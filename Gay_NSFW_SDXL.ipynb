# %% [markdown]
# <a href="https://colab.research.google.com/github/serotoninboi/fast-stable-diffusion/blob/main/Gay_NSFW_SDXL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U diffusers

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/mrcuddle/Gay-NSFW-SDXL
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/mrcuddle/Gay-NSFW-SDXL)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
pip install -U diffusers transformers accelerate

# %%
import torch
from diffusers import DiffusionPipeline

# switch to "mps" for apple devices
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", dtype=torch.bfloat16, device_map="cuda")
pipe.load_lora_weights("mrcuddle/Gay-NSFW-SDXL")

prompt = "A close-up view of two strikingly different lumberjacks locked in a passionate embrace in the heart of a dense forest. The man on the left is younger, with smooth, tanned skin, piercing green eyes, and dark hair styled in a modern undercut. He sports a well-trimmed beard that accentuates his chiseled jawline. The man on the right is older, his pale skin weathered and rugged, his blue eyes deep-set and intense beneath bushy eyebrows. His long, wild hair is a mix of gray and white, matching his thick, untamed beard. Both men wear plaid shirts in different colors, the younger man in red and black, the older man in green and blue. Their shirts are stretched taut over their broad, muscular shoulders. The forest around them is a blur of green, the trees tall and ancient. Sunlight filters through the leaves, casting a warm glow on the men's contrasting skin tones. The atmosphere is charged with raw sensuality and the thrill of an unexpected connection. rating:explicit, 2boys, male_focus, close-up, different_lumberjacks, passionate_embrace, tanned_skin, green_eyes, dark_hair, undercut, trimmed_beard, chiseled_jawline, pale_skin, weathered, blue_eyes, bushy_eyebrows, long_wild_hair, gray_white_hair, thick_untamed_beard, plaid_shirts, different_colors, broad_shoulders, dense_forest, tall_trees, warm_sunlight, contrasting_skin_tones, raw_sensuality, unexpected_connection"
image = pipe(prompt).images[0]

# %% [markdown]
# ## Remote Inference via Inference Providers
# Ensure you have a valid **HF_TOKEN** set in your environment. You can get your token from [your settings page](https://huggingface.co/settings/tokens). Note: running this may incur charges above the free tier.
# The following Python example shows how to run the model remotely on HF Inference Providers, automatically selecting an available inference provider for you.
# For more information on how to use the Inference Providers, please refer to our [documentation and guides](https://huggingface.co/docs/inference-providers/en/index).

# %%
import os
os.environ['HF_TOKEN'] = 'YOUR_TOKEN_HERE'

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="auto",
    api_key=os.environ["HF_TOKEN"],
)

# output is a PIL.Image object
image = client.text_to_image(
    "Astronaut riding a horse",
    model="mrcuddle/Gay-NSFW-SDXL",
)
